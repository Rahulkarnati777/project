# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/Environmental_Citations.csv')
data
# Out:
#         CitationNo LienCode  ...                    Location ESRI_OID
# 0          2313252        L  ...  (39.30793364,-76.65344787)        3
# 1          2708147        L  ...  (39.27839051,-76.69754927)        1
# 2          2708154        L  ...  (39.27860883,-76.69752023)        2
# 3          2708162        L  ...  (39.27888220,-76.69748387)        4
# 4          2810646        L  ...  (39.34586982,-76.67082210)        5
# ...            ...      ...  ...                         ...      ...
# 203742    56301781        L  ...  (39.33493735,-76.55483229)   198744
# 203743    56301799        L  ...  (39.29352961,-76.61925711)   198745
# 203744    56301807        L  ...  (39.35988319,-76.70206611)   198746
# 203745    56301815        L  ...  (39.28320265,-76.68380315)   198747
# 203746    56301823        L  ...  (39.32408378,-76.59141708)   198748
#
# [203747 rows x 30 columns]

# %% [markdown]
# there are 188154 rows and 30 columns in the given dataset.

# %%
data.describe()
# Out:
#          CitationNo     FineAmount  ...  CouncilDistrict       ESRI_OID
# count  2.037470e+05  203747.000000  ...    202835.000000  203747.000000
# mean   5.295345e+07     164.816380  ...         8.369818   96996.800566
# std    9.342597e+06     218.166505  ...         3.912646   58614.421121
# min    2.313252e+06      25.000000  ...         1.000000       1.000000
# 25%    5.376362e+07      50.000000  ...         6.000000   45937.500000
# 50%    5.519589e+07      50.000000  ...         9.000000   96874.000000
# 75%    5.571258e+07     200.000000  ...        12.000000  147810.500000
# max    5.630182e+07    8000.000000  ...        14.000000  198748.000000
#
# [8 rows x 9 columns]

# %% [markdown]
# describe will only run on the features of numeric datatypes.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203747 entries, 0 to 203746
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   CitationNo                  203747 non-null  int64
#  1   LienCode                    203747 non-null  object
#  2   ViolationDate               203747 non-null  object
#  3   DueDate                     203747 non-null  object
#  4   Agency                      203747 non-null  object
#  5   FineAmount                  203747 non-null  int64
#  6   Description                 203747 non-null  object
#  7   Balance                     203747 non-null  float64
#  8   LastPaidDate                95208 non-null   object
#  9   LastPaidAmount              203747 non-null  float64
#  10  HearingDate                 19618 non-null   object
#  11  HearingRequestReceivedDate  20795 non-null   object
#  12  CitationStatus              203747 non-null  object
# ...

# %% [markdown]
# from the above information we can see that there are many non-null values in the dataset and there are float,int and object datatypes.

# %%
data.isnull().sum()
# Out:
# CitationNo                         0
# LienCode                           0
# ViolationDate                      0
# DueDate                            0
# Agency                             0
# FineAmount                         0
# Description                        0
# Balance                            0
# LastPaidDate                  108539
# LastPaidAmount                     0
# HearingDate                   184129
# HearingRequestReceivedDate    182952
# CitationStatus                     0
# ViolationCodeArticle               0
# ViolationCodeSection               0
# ViolationLocation                  0
# Block                              0
# Lot                                0
# OfficerID                          0
# OfficerPresenceRequested           0
# HearingStatus                      0
# HearTime                           0
# TotalPaid                          0
# TotalAbated                        0
# TotalVoided                        0
# ...

# %% [markdown]
# we can observe that there are many null values in some coloumns.

# %% [markdown]
# Filling all null or empty cells in  original DataFrame with an empty space and set that to a new DataFrame variable which is here called the 'modifieddata'.

# %%
modifieddata=data.fillna(" ")

# %% [markdown]
# verifying if we have any null values.

# %%
modifieddata.isnull().sum()
# Out:
# CitationNo                    0
# LienCode                      0
# ViolationDate                 0
# DueDate                       0
# Agency                        0
# FineAmount                    0
# Description                   0
# Balance                       0
# LastPaidDate                  0
# LastPaidAmount                0
# HearingDate                   0
# HearingRequestReceivedDate    0
# CitationStatus                0
# ViolationCodeArticle          0
# ViolationCodeSection          0
# ViolationLocation             0
# Block                         0
# Lot                           0
# OfficerID                     0
# OfficerPresenceRequested      0
# HearingStatus                 0
# HearTime                      0
# TotalPaid                     0
# TotalAbated                   0
# TotalVoided                   0
# Neighborhood                  0
# PoliceDistrict                0
# CouncilDistrict               0
# Location                      0
# ...

# %% [markdown]
# There are no null values in the dataset. The data also have numerics like integer and float values so there is no purpose of preprocessing of data as the data is good.

# %%
modifieddata.to_csv('modifieddata.csv',index=False)

# %% [markdown]
# checking the correlation between the data.

# %%
plt.figure(figsize = (12,10))
sns.heatmap(data.corr(), annot = True, cmap = "coolwarm")
plt.title("----Correlation----", size = 23, color = "g")
plt.show()

# %% [markdown]
# we can say that there is very less or no correlation between the variables.

# %%
data.head()
# Out:
#    CitationNo LienCode  ...                    Location ESRI_OID
# 0     2313252        L  ...  (39.30793364,-76.65344787)        3
# 1     2708147        L  ...  (39.27839051,-76.69754927)        1
# 2     2708154        L  ...  (39.27860883,-76.69752023)        2
# 3     2708162        L  ...  (39.27888220,-76.69748387)        4
# 4     2810646        L  ...  (39.34586982,-76.67082210)        5
#
# [5 rows x 30 columns]

# %%
data.tail()
# Out:
#         CitationNo LienCode  ...                    Location ESRI_OID
# 203742    56301781        L  ...  (39.33493735,-76.55483229)   198744
# 203743    56301799        L  ...  (39.29352961,-76.61925711)   198745
# 203744    56301807        L  ...  (39.35988319,-76.70206611)   198746
# 203745    56301815        L  ...  (39.28320265,-76.68380315)   198747
# 203746    56301823        L  ...  (39.32408378,-76.59141708)   198748
#
# [5 rows x 30 columns]

# %% [markdown]
# plotting histograms for the columns.

# %%
data.hist(figsize = (15,8), color = "g")
plt.tight_layout()
plt.show()

# %%
sns.countplot(data['LienCode']);
